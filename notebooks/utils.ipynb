# %%
import numpy as np 
import pandas as pd
from tqdm import tqdm 
from collections import Counter 

import sys 
sys.path.append('../src/')

from utils import *

data_dir = "../data/"
filenames = ["training_pos.txt", 
             "training_neg.txt", 
             "test_pos_public.txt", 
             "test_neg_public.txt"]

# %%
posT = pd.read_csv(data_dir + filenames[0], sep="\n", header=None)
negT = pd.read_csv(data_dir + filenames[1], sep="\n", header=None)
posV = pd.read_csv(data_dir + filenames[2], sep="\n", header=None)
negV = pd.read_csv(data_dir + filenames[3], sep="\n", header=None)

# %%
# hyperparams

# %%
# utils

# %%
# TODO: Potentially need split vocabs? 
myCounter = Counter()
vocab = []

for line in lines(data_dir+filenames[0]): 
    temp1 = line.strip()
    words = temp1.split()
    myCounter.update(words)
            
for line in lines(data_dir+filenames[1]): 
    temp1 = line.strip()
    words = temp1.split()
    myCounter.update(words)
    
vocab = list(myCounter.keys())

# %%
for i, count in myCounter.items(): 
    print(i, count)
# Out:
# Kazan's 13
# early 590
# film 10864
# noir 78
# won 200
# an 8428
# Oscar. 23
# Some 386
# of 57634
# the 115227
# reviews 238
# here 1109
# go 1628
# into 3512
# extraordinary 50
# detail 87
# and 61425
# length 77
# about 6455
# its 2885
# symbolism, 6
# rate 165
# it 21588
# very 5360
# highly. 9
# I 26433
# can 4159
# almost 1178
# see 3967
# where 2317
# they 7043
# are 11371
# coming 353
# from. 38
# But 2408
# prefer 66
# to 52810
# take 1220
# a 62344
# more 5219
# toned-down 4
# approach 113
# long-forgotten 3
# that 25649
# appears 324
# have 11130
# been 3636
# shot 610
# on 12238
# practically 72
# no 4071
# budget 441
# in 34856
# quasi-documentary 2
# fashion. 29
# Pneumonic 3
# plague 37
# is 41602
# loose 88
# streets 53
# New 506
# Orleans, 13
# up 4251
# military 152
# doctor 124
# (Widmark) 3
# city 224
# detective 128
# (Douglas) 1
# apprehend 2
# main 854
# carrier 7
# (Palance). 1
# The 13701
# moody, 8
# stark 32
# black 489
# white, 30
# makes 1719
# ...
